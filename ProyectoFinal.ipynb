# %% [markdown]
# <a href="https://colab.research.google.com/github/RosyBacelis/FinalHerra/blob/main/ProyectoFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerias que se requiere
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Agregamos el archivo csv
#Cargar los datos
df = pd.read_csv("/content/drive/MyDrive/final/Laptop-Users.csv")
df
# Out:
#     Age  Gender       Region Occupation  Income Has Laptop
# 0    14    male         city    student       0         no
# 1    34  female         city    teacher   22000         no
# 2    42    male  countryside     banker   24000        yes
# 3    30    male  countryside    teacher   25000         no
# 4    16    male         city    student       0         no
# 5    33  female         city     banker   20000        yes
# 6    26  female         city    student    8000        yes
# 7    22    male         city    student    4000        yes
# 8    28  female  countryside    teacher   12000         no
# 9    27  female         city    student    7000        yes
# 10   19    male         city    student   10000         no
# 11   26  female         city    student   11000        yes
# 12   29  female  countryside     banker   18000        yes
# 13   36    male  countryside     banker   26000         no
# 14   35    male         city    student    8000        yes
# ...

# %%
#Obtiene la forma de los datos
df.shape
# Out:
# (20, 6)

# %%
#Obtiene los tipos de datos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         20 non-null     int64
#  1   Gender      20 non-null     object
#  2   Region      20 non-null     object
#  3   Occupation  20 non-null     object
#  4   Income      20 non-null     int64
#  5   Has Laptop  20 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %%
#Comprobando los valores nulos
df.isnull().sum()
# Out:
# Age           0
# Gender        0
# Region        0
# Occupation    0
# Income        0
# Has Laptop    0
# dtype: int64

# %%
# Resumiendo los datos
df.describe().T
# Out:
#         count     mean          std   min     25%      50%       75%      max
# Age      20.0     30.2    10.904369  14.0    25.0     28.5     35.25     54.0
# Income   20.0  14650.0  9745.579295   0.0  7750.0  13000.0  24250.00  30000.0

# %% [markdown]
# VISUALIZACION

# %%
# Crear figuras y subparcelas
# Graficar cada eje
def hist_count(column, data):
    if column in data:
        f, axes = plt.subplots(1,1,figsize=(15,5))
        sns.countplot(x=column, data=data)
        plt.xticks(rotation = 90)
        plt.suptitle(column, fontsize=20)
        plt.show()
    plt.show()
for column in df.columns:
    hist_count(column,df)

# %%
# Age and Laptop
import plotly.express as px
fig = px.histogram(df, x = df['Age'], color = 'Has Laptop')
fig.show()
fig2 = px.box(df, x = df['Age'], color = 'Has Laptop')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
